# %% [markdown]
# ### LSE Data Analytics Online Career Accelerator
#
# # DA201: Data Analytics Using Python

# %% [markdown]
# ## Practical activity: Highlight and annotate plots

# %% [markdown]
# # Scenario
# Canopy is a new boutique streaming company that is looking to create an app that provides recommendations based on the last movie users watch.
#
# # Objective
# You have access to the data sets movies.csv and ott.xlsx from Canopy. You have already created some good plots (bar, scatter, point, count, histograms, and lineplots) for Canopy and explored the trends and outliers in the data. Based on the plots created so far, in this activity, we will:
#
# - Customise the existing scatter, box, and lineplots.
# - Add more customisations to extract further information from the scatterplots and countplots.

# %% [markdown]
# ## 1. Import the libraries

# %%
# Import necessary libraries.
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Import Excel file

# %%
# Load the Excel data using pd.read_excel.
ott = pd.read_excel('ott.xlsx')

print(ott.columns)
# Out:
# Index(['ID', 'Netflix', 'Hulu', 'Prime Video', 'Disney+'], dtype='object')

# %% [markdown]
# ## 3. Import CSV file

# %%
# Load the CSV data using pd.read_csv.
movies = pd.read_csv('movies.csv')

print(movies.columns)
# Out:
# Index(['ID', 'Title', 'Year', 'Age', 'IMDb', 'Rotten Tomatoes', 'Directors',
#        'Genres', 'Country', 'Language', 'Runtime'],
#       dtype='object')

# %% [markdown]
# ## 4. Validate the DataFrames

# %%
# Data imported correctly?
print(movies.head())
print(movies.shape)
print(movies.dtypes)
# Out:
#    ID                           Title  Year  Age  IMDb Rotten Tomatoes  \
# 0   1                       Inception  2010  13+   8.8             87%
# 1   2                      The Matrix  1999  18+   8.7             87%
# 2   3          Avengers: Infinity War  2018  13+   8.5             84%
# 3   4              Back to the Future  1985   7+   8.5             96%
# 4   5  The Good, the Bad and the Ugly  1966  18+   8.8             97%
#
#                         Directors                            Genres  \
# 0               Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# 1  Lana Wachowski,Lilly Wachowski                     Action,Sci-Fi
# 2         Anthony Russo,Joe Russo           Action,Adventure,Sci-Fi
# 3                 Robert Zemeckis           Adventure,Comedy,Sci-Fi
# 4                    Sergio Leone                           Western
#
#                         Country                 Language  Runtime
# 0  United States,United Kingdom  English,Japanese,French    148.0
# 1                 United States                  English    136.0
# 2                 United States                  English    149.0
# 3                 United States                  English    116.0
# 4      Italy,Spain,West Germany                  Italian    161.0
# (16744, 11)
# ID                   int64
# Title               object
# Year                 int64
# Age                 object
# IMDb               float64
# Rotten Tomatoes     object
# Directors           object
# Genres              object
# Country             object
# Language            object
# Runtime            float64
# dtype: object

# %%
# Data imported correctly?
print(ott.head())
print(ott.dtypes)
print(ott.shape)
# Out:
#    ID  Netflix  Hulu  Prime Video  Disney+
# 0   1        0     0            1        0
# 1   2        0     1            0        0
# 2   3        0     0            1        0
# 3   4        1     0            0        0
# 4   5        0     0            1        0
# ID             int64
# Netflix        int64
# Hulu           int64
# Prime Video    int64
# Disney+        int64
# dtype: object
# (16744, 5)

# %% [markdown]
# ## 5. Combine the two DataFrames

# %%
# Merge the two DataFrames.
mov_ott = pd.merge(movies, ott, how='left', on = 'ID')

# View the DataFrame.
print(mov_ott.shape)
mov_ott.head()
# Out:
# (16744, 15)
#    ID                           Title  Year  Age  IMDb Rotten Tomatoes  \
# 0   1                       Inception  2010  13+   8.8             87%
# 1   2                      The Matrix  1999  18+   8.7             87%
# 2   3          Avengers: Infinity War  2018  13+   8.5             84%
# 3   4              Back to the Future  1985   7+   8.5             96%
# 4   5  The Good, the Bad and the Ugly  1966  18+   8.8             97%
#
#                         Directors                            Genres  \
# 0               Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# 1  Lana Wachowski,Lilly Wachowski                     Action,Sci-Fi
# 2         Anthony Russo,Joe Russo           Action,Adventure,Sci-Fi
# 3                 Robert Zemeckis           Adventure,Comedy,Sci-Fi
# 4                    Sergio Leone                           Western
#
#                         Country                 Language  Runtime  Netflix  \
# 0  United States,United Kingdom  English,Japanese,French    148.0        0
# 1                 United States                  English    136.0        0
# 2                 United States                  English    149.0        0
# 3                 United States                  English    116.0        1
# 4      Italy,Spain,West Germany                  Italian    161.0        0
#
#    Hulu  Prime Video  Disney+
# 0     0            1        0
# 1     1            0        0
# 2     0            1        0
# 3     0            0        0
# 4     0            1        0

# %% [markdown]
# ## 6. Create a countplot

# %%
# Create a countplot based on number of movies streamed by Netflix per age group.
sns.countplot(x='Age', hue='Netflix', data=mov_ott)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %% [markdown]
# ## 7. Create a histogram

# %%
# Create a histogram based on IMDb. 
sns.histplot(data=mov_ott, x='IMDb', binwidth=1)
# Out:
# <Axes: xlabel='IMDb', ylabel='Count'>

# %% [markdown]
# ## 8. Create a scatterplot

# %%
# Create scatterplot with two variables (IMDb and Rotten Tomatoes).
sns.scatterplot(x='IMDb', y='Rotten Tomatoes', data=mov_ott)
# Out:
# <Axes: xlabel='IMDb', ylabel='Rotten Tomatoes'>

# %% [markdown]
# ## 9. Create a lineplot

# %%
# Create a simple lineplot.
sns.lineplot(x='Year', y='IMDb', data=mov_ott)
# Out:
# <Axes: xlabel='Year', ylabel='IMDb'>

# %%
# Create a simple lineplot.
sns.lineplot(x='Year', y='IMDb', data=mov_ott, ci=None)
# Out:
# /var/folders/cn/47qy272s11q7_n4t9zj37np40000gn/T/ipykernel_4176/1389212160.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='Year', y='IMDb', data=mov_ott, ci=None)
# <Axes: xlabel='Year', ylabel='IMDb'>

# %%
# Create lineplots with specification.
sns.lineplot(x = 'Year', y = 'IMDb',
             data=mov_ott[mov_ott['Age'].isin(['16+', '18+'])],
             hue ="Age")
# Out:
# <Axes: xlabel='Year', ylabel='IMDb'>

# %%
# Create lineplots with specification.
sns.lineplot(x = 'Year', y = 'IMDb',
             data=mov_ott[mov_ott['Age'].isin(['16+', '18+'])],
             hue ='Age', ci=None)
# Out:
# /var/folders/cn/47qy272s11q7_n4t9zj37np40000gn/T/ipykernel_4176/1848823367.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x = 'Year', y = 'IMDb',
# <Axes: xlabel='Year', ylabel='IMDb'>

# %% [markdown]
# ## 10. Customise plots

# %% [markdown]
# ### Barplot

# %%
mov_ott_2010 = mov_ott[mov_ott['Year']>=2010]

ax = sns.countplot(x='Year', data=mov_ott_2010)

ax.set(ylabel='Percent')

total = len(mov_ott_2010['Year'])

for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x()
    y = p.get_y() + p.get_height()
    ax.annotate(percentage, (x, y))

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Histogram

# %%
ax = sns.displot(data=mov_ott, x='IMDb', bins=10,kind='hist', 
                 palette='GnBu', aspect=1.4, kde=True)

plt.show()
# Out:
# /var/folders/cn/47qy272s11q7_n4t9zj37np40000gn/T/ipykernel_4176/869438397.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   ax = sns.displot(data=mov_ott, x='IMDb', bins=10,kind='hist',

# %% [markdown]
# ## 11. Highlight and annotate plots

# %% [markdown]
# ### Scatterplot

# %%
sns.scatterplot(data=mov_ott, x='IMDb', y='Rotten Tomatoes', hue='Netflix')

plt.show()

# %% [markdown]
# ### Boxplot

# %%
sns.boxplot(data=mov_ott, x='Age', y='IMDb', linewidth=2, 
            notch=True, hue='Netflix', palette='Set3')

plt.show()

# %% [markdown]
# ### Lineplot

# %%
sns.lineplot(x = 'Year', y = 'IMDb', data=mov_ott, linewidth=0)
# Out:
# <Axes: xlabel='Year', ylabel='IMDb'>

# %%
sns.lineplot(x = 'Year', y = 'IMDb',
             data=mov_ott[mov_ott['Age'].isin(['16+', '18+'])], 
             hue ='Age')
# Out:
# <Axes: xlabel='Year', ylabel='IMDb'>

# %%
sns.lineplot(x = 'Year', y = 'IMDb', 
             data=mov_ott[mov_ott['Age'].isin(['16+', '18+'])], 
             hue ='Age', style = 'Age', markers=True, ci=0)
# Out:
# /var/folders/cn/47qy272s11q7_n4t9zj37np40000gn/T/ipykernel_4176/485187738.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 0)` for the same effect.
#
#   sns.lineplot(x = 'Year', y = 'IMDb',
# <Axes: xlabel='Year', ylabel='IMDb'>

# %%
sns.lineplot(x = 'Year', y = 'IMDb', data=mov_ott, linewidth=0)

sns.lineplot(x = 'Year', y = 'IMDb',
             data=mov_ott[mov_ott['Age'].isin(['16+', '18+'])], 
             hue ='Age')

sns.lineplot(x = 'Year', y = 'IMDb', 
             data=mov_ott[mov_ott['Age'].isin(['16+', '18+'])], 
             hue ='Age', style = 'Age', markers=True, ci=0)
# Out:
# /var/folders/cn/47qy272s11q7_n4t9zj37np40000gn/T/ipykernel_4176/2838425111.py:7: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 0)` for the same effect.
#
#   sns.lineplot(x = 'Year', y = 'IMDb',
# <Axes: xlabel='Year', ylabel='IMDb'>
