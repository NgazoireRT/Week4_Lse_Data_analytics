# %% [markdown]
# # 4.1.15 Practical activity: Creating line charts and subplots

# %% [markdown]
# ## Practical activity: Create line and subplots

# %% [markdown]
# # Scenario
#
# Canopy is a new boutique streaming company that is looking to create an app that provides recommendations based on the last movie you watched.
#
# As a part of their process, they want to review the data and gather enough information before they start making suggestions and recommendations to their clients.
#
# This analysis uses the `movies.csv` and `ott.xlsx` data sets. Based on the available information,
#
# # Objective
#
# - create a line chart to help identify trends in the data and spot or track interesting relationships among the variables
# - understand what the data says by visualising it with lineplots.

# %% [markdown]
# ## 1. Import the libraries

# %%
# Import necessary libraries.
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Import Excel file

# %%
# Load the Excel data using pd.read_excel.
ott = pd.read_excel('ott.xlsx')

# View the columns.
print(ott.columns)
# Out:
# Index(['ID', 'Netflix', 'Hulu', 'Prime Video', 'Disney+'], dtype='object')

# %% [markdown]
# ## 3. Import CSV file

# %%
# Load the CSV data using pd.read_csv.
movies = pd.read_csv('movies.csv')

print(movies.columns)
# Out:
# Index(['ID', 'Title', 'Year', 'Age', 'IMDb', 'Rotten Tomatoes', 'Directors',
#        'Genres', 'Country', 'Language', 'Runtime'],
#       dtype='object')

# %% [markdown]
# ## 4. Validate the DataFrames

# %%
# Data imported correctly?
print(movies.head())
print(movies.shape)
print(movies.dtypes)
# Out:
#    ID                           Title  Year  Age  IMDb Rotten Tomatoes  \
# 0   1                       Inception  2010  13+   8.8             87%
# 1   2                      The Matrix  1999  18+   8.7             87%
# 2   3          Avengers: Infinity War  2018  13+   8.5             84%
# 3   4              Back to the Future  1985   7+   8.5             96%
# 4   5  The Good, the Bad and the Ugly  1966  18+   8.8             97%
#
#                         Directors                            Genres  \
# 0               Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# 1  Lana Wachowski,Lilly Wachowski                     Action,Sci-Fi
# 2         Anthony Russo,Joe Russo           Action,Adventure,Sci-Fi
# 3                 Robert Zemeckis           Adventure,Comedy,Sci-Fi
# 4                    Sergio Leone                           Western
#
#                         Country                 Language  Runtime
# 0  United States,United Kingdom  English,Japanese,French    148.0
# 1                 United States                  English    136.0
# 2                 United States                  English    149.0
# 3                 United States                  English    116.0
# 4      Italy,Spain,West Germany                  Italian    161.0
# (16744, 11)
# ID                   int64
# Title               object
# Year                 int64
# Age                 object
# IMDb               float64
# Rotten Tomatoes     object
# Directors           object
# Genres              object
# Country             object
# Language            object
# Runtime            float64
# dtype: object

# %%
# Data imported correctly.
print(ott.head())
print(ott.dtypes)
print(ott.shape)
# Out:
#    ID  Netflix  Hulu  Prime Video  Disney+
# 0   1        0     0            1        0
# 1   2        0     1            0        0
# 2   3        0     0            1        0
# 3   4        1     0            0        0
# 4   5        0     0            1        0
# ID             int64
# Netflix        int64
# Hulu           int64
# Prime Video    int64
# Disney+        int64
# dtype: object
# (16744, 5)

# %% [markdown]
# ## 5. Combine the two DataFrames

# %%
# Merge the two DataFrames.
mov_ott = pd.merge(movies, ott, how='left', on = 'ID')

# View the DataFrame.
print(mov_ott.shape)
mov_ott.head()
# Out:
# (16744, 15)
#    ID                           Title  Year  Age  IMDb Rotten Tomatoes  \
# 0   1                       Inception  2010  13+   8.8             87%
# 1   2                      The Matrix  1999  18+   8.7             87%
# 2   3          Avengers: Infinity War  2018  13+   8.5             84%
# 3   4              Back to the Future  1985   7+   8.5             96%
# 4   5  The Good, the Bad and the Ugly  1966  18+   8.8             97%
#
#                         Directors                            Genres  \
# 0               Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# 1  Lana Wachowski,Lilly Wachowski                     Action,Sci-Fi
# 2         Anthony Russo,Joe Russo           Action,Adventure,Sci-Fi
# 3                 Robert Zemeckis           Adventure,Comedy,Sci-Fi
# 4                    Sergio Leone                           Western
#
#                         Country                 Language  Runtime  Netflix  \
# 0  United States,United Kingdom  English,Japanese,French    148.0        0
# 1                 United States                  English    136.0        0
# 2                 United States                  English    149.0        0
# 3                 United States                  English    116.0        1
# 4      Italy,Spain,West Germany                  Italian    161.0        0
#
#    Hulu  Prime Video  Disney+
# 0     0            1        0
# 1     1            0        0
# 2     0            1        0
# 3     0            0        0
# 4     0            1        0

# %% [markdown]
# ## 6. Create a lineplot

# %%
# Create a simple lineplot.
sns.lineplot(x='Year', y='IMDb', data=mov_ott)
# Out:
# <Axes: xlabel='Year', ylabel='IMDb'>

# %%
# Create a simple lineplot.
sns.lineplot(x='Year', y='IMDb', data=mov_ott, ci=None)
# Out:
# /var/folders/cn/47qy272s11q7_n4t9zj37np40000gn/T/ipykernel_23047/1389212160.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='Year', y='IMDb', data=mov_ott, ci=None)
# <Axes: xlabel='Year', ylabel='IMDb'>

# %%
# Create lineplots with specification.
sns.lineplot(x = 'Year', y = 'IMDb',
             data=mov_ott[mov_ott['Age'].isin(['16+', '18+'])],
             hue ='Age')
# Out:
# <Axes: xlabel='Year', ylabel='IMDb'>

# %%
# Create lineplots with specification.
sns.lineplot(x = 'Year', y = 'IMDb',
             data=mov_ott[mov_ott['Age'].isin(['16+', '18+'])],
             hue ='Age', ci=None)
# Out:
# /var/folders/cn/47qy272s11q7_n4t9zj37np40000gn/T/ipykernel_23047/1848823367.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x = 'Year', y = 'IMDb',
# <Axes: xlabel='Year', ylabel='IMDb'>
