# %% [markdown]
# # DA201: Data Analytics Using Python

# %% [markdown]
# ## Practical activity: Create plots with Seaborn

# %% [markdown]
# # Scenario
# Canopy is a new boutique streaming company that is looking to create an app that provides recommendations based on the last movie users watch. As a part of its process, before Canopy starts making suggestions and recommendations to its clients, it wants to understand the data.
#
# # Objective
# You have access to the data sets movies.csv and ott.xlsx from Canopy. Based on the data sets, Canopy asks you to:
#
# Perform an exploratory analysis of the data to:
# Identify underlying patterns within the data.
# Detect outliers or anomalies.
# Find relevant relations among the variables.
# Provide visual representations of the data using the most suitable plot type (scatterplot, histogram, etc.)

# %% [markdown]
# ## 1. Import the libraries

# %%
# Import Pandas, Seaborn, and Matplotlib.
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Import Excel file

# %%
# Load the Excel data using pd.read_excel.
ott = pd.read_excel('ott.xlsx')

# View the columns.
print(ott.columns)
# Out:
# Index(['ID', 'Netflix', 'Hulu', 'Prime Video', 'Disney+'], dtype='object')

# %% [markdown]
# ## 3. Import CSV file

# %%
# Load the CSV data using pd.read_csv.
movies = pd.read_csv('movies.csv')

# View the columns.
print(movies.columns)
print(movies.shape)
# Out:
# Index(['ID', 'Title', 'Year', 'Age', 'IMDb', 'Rotten Tomatoes', 'Directors',
#        'Genres', 'Country', 'Language', 'Runtime'],
#       dtype='object')
# (16744, 11)

# %% [markdown]
# ## 4. Validate the DataFrames

# %%
# Data imported correctly?
print(movies.head())
print(movies.shape)
print(movies.dtypes)
# Out:
#    ID                           Title  Year  Age  IMDb Rotten Tomatoes  \
# 0   1                       Inception  2010  13+   8.8             87%
# 1   2                      The Matrix  1999  18+   8.7             87%
# 2   3          Avengers: Infinity War  2018  13+   8.5             84%
# 3   4              Back to the Future  1985   7+   8.5             96%
# 4   5  The Good, the Bad and the Ugly  1966  18+   8.8             97%
#
#                         Directors                            Genres  \
# 0               Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# 1  Lana Wachowski,Lilly Wachowski                     Action,Sci-Fi
# 2         Anthony Russo,Joe Russo           Action,Adventure,Sci-Fi
# 3                 Robert Zemeckis           Adventure,Comedy,Sci-Fi
# 4                    Sergio Leone                           Western
#
#                         Country                 Language  Runtime
# ...

# %%
# Data imported correctly?
print(ott.head())
print(ott.dtypes)
print(ott.shape)
# Out:
#    ID  Netflix  Hulu  Prime Video  Disney+
# 0   1        0     0            1        0
# 1   2        0     1            0        0
# 2   3        0     0            1        0
# 3   4        1     0            0        0
# 4   5        0     0            1        0
# ID             int64
# Netflix        int64
# Hulu           int64
# Prime Video    int64
# Disney+        int64
# dtype: object
# (16744, 5)

# %% [markdown]
# ## 5. Combine the two DataFrames

# %%
# Merge the two DataFrames.
mov_ott = pd.merge(movies, ott, how='left', on = 'ID')

# View the DataFrame.
print(mov_ott.shape)
mov_ott.head()
# Out:
# (16744, 15)
#    ID                           Title  Year  Age  IMDb Rotten Tomatoes  \
# 0   1                       Inception  2010  13+   8.8             87%
# 1   2                      The Matrix  1999  18+   8.7             87%
# 2   3          Avengers: Infinity War  2018  13+   8.5             84%
# 3   4              Back to the Future  1985   7+   8.5             96%
# 4   5  The Good, the Bad and the Ugly  1966  18+   8.8             97%
#
#                         Directors                            Genres  \
# 0               Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# 1  Lana Wachowski,Lilly Wachowski                     Action,Sci-Fi
# 2         Anthony Russo,Joe Russo           Action,Adventure,Sci-Fi
# 3                 Robert Zemeckis           Adventure,Comedy,Sci-Fi
# 4                    Sergio Leone                           Western
#
#                         Country                 Language  Runtime  Netflix  \
# ...

# %% [markdown]
# ## 6. Create a countplot

# %%
# Create a countplot based on number of movies streamed by Netflix per age group.
sns.countplot(x='Age', hue='Netflix', data=mov_ott)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %% [markdown]
# ## 7. Create a histogram

# %%
# Create a histogram based on IMDb. 
sns.histplot(data=mov_ott, x='IMDb', binwidth=1)
# Out:
# <Axes: xlabel='IMDb', ylabel='Count'>

# %% [markdown]
# ## 8. Create a scatterplot

# %%
# Create a scatterplot with two variables (IMDb and Rotten Tomatoes).
sns.scatterplot(x='IMDb', y='Rotten Tomatoes', data=mov_ott, color='olive')
# Out:
# <Axes: xlabel='IMDb', ylabel='Rotten Tomatoes'>

# %% [markdown]
# Answer the following questions, based on the plot:
#
# What can you infer about the correlation? - Strong concentration between rating of 4.5-7.5 given the high density
#
# If there is a correlation, is the relationship between the ratings strong or weak and positive or negative? Positive relationship in cluster format.
