# %% [markdown]
# # Print and pixel
# Select the tabs to deepen your understanding on how to set pixel size and print or save your visualisations.
#
#
# # Setting the resolution
# First, let's practise setting the DPI of the figure when it’s created simply using the DPI argument in the subplots() function. Launch Jupyter Notebook and create a new Python3 file, and then create a six by four inch figure at 150 DPI.

# %%
# Import Seaborn and Matplotlib.
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(dpi=150)

fig.set_size_inches(6, 4)

# %%
fig, ax = plt.subplots(dpi=100)

fig.set_size_inches(8, 6)

# %%
# Saving the visualisation. 

fig.savefig('my_plot.png')

fig.savefig('my_plot.jpg')

# %%
fig.savefig('my_plot_print.png', dpi=300)

fig.savefig('my_plot_web.png', dpi=72)

# %% [markdown]
# all these images saved on your my system automatically. Please refer to your system folder to open these images in their respective formats.
